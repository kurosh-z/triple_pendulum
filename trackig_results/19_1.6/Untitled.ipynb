# %%
import numpy as np

# %%
tvec=np.load('simulation_time.npy')

# %%
tvec
# Out:
# array([0.        , 0.00417755, 0.00835509, 0.01253264, 0.01671018,
#        0.02088773, 0.02506527, 0.02924282, 0.03342037, 0.03759791,
#        0.04177546, 0.045953  , 0.05013055, 0.05430809, 0.05848564,
#        0.06266319, 0.06684073, 0.07101828, 0.07519582, 0.07937337,
#        0.08355091, 0.08772846, 0.09190601, 0.09608355, 0.1002611 ,
#        0.10443864, 0.10861619, 0.11279373, 0.11697128, 0.12114883,
#        0.12532637, 0.12950392, 0.13368146, 0.13785901, 0.14203655,
#        0.1462141 , 0.15039164, 0.15456919, 0.15874674, 0.16292428,
#        0.16710183, 0.17127937, 0.17545692, 0.17963446, 0.18381201,
#        0.18798956, 0.1921671 , 0.19634465, 0.20052219, 0.20469974,
#        0.20887728, 0.21305483, 0.21723238, 0.22140992, 0.22558747,
#        0.22976501, 0.23394256, 0.2381201 , 0.24229765, 0.2464752 ,
#        0.25065274, 0.25483029, 0.25900783, 0.26318538, 0.26736292,
#        0.27154047, 0.27571802, 0.27989556, 0.28407311, 0.28825065,
# ...

# %%
t=0.15
a=np.absolute(tvec-t)

# %%
a
# Out:
# array([1.50000000e-01, 1.45822454e-01, 1.41644909e-01, 1.37467363e-01,
#        1.33289817e-01, 1.29112272e-01, 1.24934726e-01, 1.20757180e-01,
#        1.16579634e-01, 1.12402089e-01, 1.08224543e-01, 1.04046997e-01,
#        9.98694517e-02, 9.56919060e-02, 9.15143603e-02, 8.73368146e-02,
#        8.31592689e-02, 7.89817232e-02, 7.48041775e-02, 7.06266319e-02,
#        6.64490862e-02, 6.22715405e-02, 5.80939948e-02, 5.39164491e-02,
#        4.97389034e-02, 4.55613577e-02, 4.13838120e-02, 3.72062663e-02,
#        3.30287206e-02, 2.88511749e-02, 2.46736292e-02, 2.04960836e-02,
#        1.63185379e-02, 1.21409922e-02, 7.96344648e-03, 3.78590078e-03,
#        3.91644909e-04, 4.56919060e-03, 8.74673629e-03, 1.29242820e-02,
#        1.71018277e-02, 2.12793734e-02, 2.54569191e-02, 2.96344648e-02,
#        3.38120104e-02, 3.79895561e-02, 4.21671018e-02, 4.63446475e-02,
#        5.05221932e-02, 5.46997389e-02, 5.88772846e-02, 6.30548303e-02,
# ...

# %%
ind= np.unravel_index(np.argmin(a, axis=None), a.shape)

# %%
ind=ind[0]

# %%
tvec[ind:]
# Out:
# array([0.15039164, 0.15456919, 0.15874674, 0.16292428, 0.16710183,
#        0.17127937, 0.17545692, 0.17963446, 0.18381201, 0.18798956,
#        0.1921671 , 0.19634465, 0.20052219, 0.20469974, 0.20887728,
#        0.21305483, 0.21723238, 0.22140992, 0.22558747, 0.22976501,
#        0.23394256, 0.2381201 , 0.24229765, 0.2464752 , 0.25065274,
#        0.25483029, 0.25900783, 0.26318538, 0.26736292, 0.27154047,
#        0.27571802, 0.27989556, 0.28407311, 0.28825065, 0.2924282 ,
#        0.29660574, 0.30078329, 0.30496084, 0.30913838, 0.31331593,
#        0.31749347, 0.32167102, 0.32584856, 0.33002611, 0.33420366,
#        0.3383812 , 0.34255875, 0.34673629, 0.35091384, 0.35509138,
#        0.35926893, 0.36344648, 0.36762402, 0.37180157, 0.37597911,
#        0.38015666, 0.3843342 , 0.38851175, 0.3926893 , 0.39686684,
#        0.40104439, 0.40522193, 0.40939948, 0.41357702, 0.41775457,
#        0.42193211, 0.42610966, 0.43028721, 0.43446475, 0.4386423 ,
# ...
