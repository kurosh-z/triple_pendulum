# %%
label='Inverted' + '_' + 'triple' +'_' +'Pendulum'
states= np.load('C:\\robotics\\triple_pendulum\\results_triple\\test6_Abweichung\\'+'x_closed_loop_Inverted_triple_Pendulum_max_time_2.npy')
x_traj= np.load('C:\\robotics\\triple_pendulum\\results_triple\\test6_Abweichung\\'+'x_traj_Inverted_triple_Pendulum_max_time_2.npy')
k_matrix=np.load('C:\\robotics\\triple_pendulum\\results_triple\\test6_Abweichung\\'+'K_matrix_Inverted_triple_Pendulum_max_time_2.npy')

# %%
from matplotlib import pyplot as plt

# %%
# q1-q3 :

frames_per_sec = 120
final_time = 2
tvec = np.linspace(0.0, final_time, final_time * frames_per_sec)
tvec2= np.linspace(0., 2, 1000)

phis= states[:,1:4]* 180/ np.pi

phi_traj=x_traj[:,1:4]*180/np.pi

fig , axes = plt.subplots(figsize=(15,5))
axes.plot(tvec[::3], phis[:,0][::3], 'ro', label='$q_1$' )
axes.plot(tvec[::3], phis[:,1][::3], 'ro',color='blue', label='$q_2$'  )
axes.plot(tvec[::3], phis[:,2][::3], 'ro',color='green', label='$q_3$'  )

axes.plot(tvec2, phi_traj[:,0], color='red',label='$q_1ref$')
axes.plot(tvec2, phi_traj[:,1], color='blue',label='$q_2ref$')
axes.plot(tvec2, phi_traj[:,2], color='green',label='$q_3ref$')

axes.set_xlabel('Zeit (s)')
axes.set_ylabel('Winkel (Grad)')
axes.legend(loc=1)
axes.grid(True)

# %%
# angular velocities :
phi_dots= states[:,4:]
phi_dot_traj=x_traj[:,4:]

fig , axes = plt.subplots(figsize=(15,5))
axes.plot(tvec[::3], phi_dots[:,0][::3], 'ro', label='$\dot{q_1}$' )
axes.plot(tvec[::3], phi_dots[:,1][::3], 'ro',color='blue', label='$\dot{q_2}$'  )
axes.plot(tvec[::3], phi_dots[:,2][::3], 'ro',color='green', label='$\dot{q_3}$'  )

axes.plot(tvec2, phi_dot_traj[:,0], color='red',label='$\dot{q_1}ref$')
axes.plot(tvec2, phi_dot_traj[:,1], color='blue',label='$\dot{q_2}ref$')
axes.plot(tvec2, phi_dot_traj[:,2], color='green',label='$\dot{q_3}ref$')

axes.set_xlabel('Zeit (s)')
axes.set_ylabel('Winkelgeschwindigkeit (rad/s)')
axes.legend(loc=4)
axes.grid(True)

# %%
# q0 :

# %%
fig , axes = plt.subplots(figsize=(15,5))
axes.plot(tvec, k_matrix[:,0], '--r', color= 'magenta', label='$k_0$' )
axes.plot(tvec, k_matrix[:,1], '--r',color='blue', label='$k_1$'  )
axes.plot(tvec, k_matrix[:,2], '--r',color='cyan', label='$k_2$' )
axes.plot(tvec, k_matrix[:,3], '--r',color='black', label='$k_3$' )
axes.plot(tvec, k_matrix[:,4], '--r',color='green', label='$k_4$' )
axes.plot(tvec, k_matrix[:,5], '--r',color='yellow', label='$k_5$' )
axes.plot(tvec, k_matrix[:,6], '--r', color='red', label='$k_6$' )
axes.plot(tvec, k_matrix[:,7], '--r', color='brown', label='$k_7$' )


axes.set_xlabel('Zeit (s)')
axes.set_ylabel('Folgereglerversarkung')
axes.legend(loc=2)
axes.grid(True)

# %%
ct=cfg.pendata

# %%
fr= ct.model.fr
frstar= ct.model.fstar 
mass_matrix= ct.model.mass_matrix 
mass_matrix_simplified= ct.model.mass_matrix_simplified
forcing_vector= ct.model.forcing_vector
